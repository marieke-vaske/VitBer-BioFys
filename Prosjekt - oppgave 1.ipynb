# %% [markdown]
# # Introduksjon til vitenskapelige beregninger prosjekt

# %% [markdown]
# # Oppgave 1a
# $\phi(x,t) = \frac{1}{\sqrt{4\pi Dt}} \cdot \int_{-\infty}^{\infty} h(y)\cdot exp\frac{-(x-y)^2}{4Dt} dy$
#
# Diffusjonsligning: $\frac{\partial}{\partial t}\phi = D\cdot \frac{\partial^2}{\partial x^2}\phi$
# For å vise at $\phi(x,t)$ løser diffusjonsligningen, må vi finne $\frac{\partial}{\partial t}\phi = \phi_x$ og $\frac{\partial^2}{\partial x^2}\phi = \phi_{tt}$
# $\phi_t = \frac{1}{\sqrt{4\pi D}} \cdot \left(\frac{-1}{2 t^{\frac{3}{2}}}\cdot \int_{-\infty}^{\infty} h(y)\cdot exp\frac{-(x-y)^2}{4Dt}dy + \frac{1}{4 D t^{\frac{5}{2}}}\cdot \int_{-\infty}^{\infty} h(y)\cdot (x-y)^2 exp\frac{-(x-y)^2}{4Dt}dy \right)$
#
# $\phi_x = \frac{1}{\sqrt{4\pi D}} \frac{1}{t^{\frac{1}{2}}}\cdot \int_{-\infty}^{\infty} h(y)\cdot \frac{-(x-y)}{2Dt} exp\frac{-(x-y)^2}{4Dt} dy$
#
# $\phi_{xx} = \frac{1}{\sqrt{4\pi D}}\cdot \frac{1}{D} \cdot \left(\frac{-1}{2 t^{\frac{3}{2}}}\cdot \int_{-\infty}^{\infty} h(y)\cdot exp\frac{-(x-y)^2}{4Dt}dy + \frac{1}{4 D t^{\frac{5}{2}}}\cdot \int_{-\infty}^{\infty} h(y)\cdot (x-y)^2 exp\frac{-(x-y)^2}{4Dt}dy \right)$
#
# Og da viser dette at $\phi(x,t)$ løser diffusjonsligningen.
# Når $t \to 0$ blir $\frac{1}{\sqrt{4\pi Dt}} exp\frac{-(x-y)^2}{4Dt} \to \delta(x-y)$ og da blir $\phi(x,0) = \int_{-\infty}^{\infty} h(y)\cdot \delta(x-y) dy = h(x)$. Dette viser at $h(x)$ representerer initial fordelingen av partiklene i punkt $x$

# %% [markdown]
# # Oppgave 1b
#
# $P(x) = \frac{e^{-\beta V(x)}}{Z}$
#
# $Z =  \sum_{i=0}^{n} e^{-\beta E_{i}}, E_{i}=V(x_{i}) $
#
# Utregning av Z ved å summere over oppgitte $x_{0} \epsilon \{x-1, x, x+1\} $ og innsetting i P(x) gir sannsynlighetene:
#
# $p^{+} = \frac{e^{-\beta V(x+1)}}{e^{-\beta V(x-1)}+e^{-\beta V(x)}+e^{-\beta V(x+1)}} $
#
# Vi kan dele på $e^{-\beta V(x+1)}$, omrokkere litt og få:
#
# $p^{+} = \frac{1}{1+e^{-\beta (V(x)-V(x+1))}+e^{-\beta (V(x+1)-V(x-1))}}$
#
# Tilsvarende kan gjentas for alle potensialene. Slik at vi får:
#
# $p^{0} = \frac{1}{1+e^{-\beta (V(x-1)-V(x))}+e^{-\beta (V(x+1)-V(x))}}$
#
# $p^{-} = \frac{1}{1+e^{-\beta (V(x+1)-V(x-1))}+e^{-\beta (V(x)-V(x-1))}}$

# %% [markdown]
# # Oppgave 1c
#
# I denne oppgaven skal vi undersøke grensetilfellene der den termiske energien er mye mindre eller mye større enn potensialforskjellen mellom to posisjoner ved siden av hverandre.
#
# De to tilfellene er $k_{B}T\gg\|V(x+1)-V(x)\|$ og $k_{B}T\ll\|V(x+1)-V(x)\|$.<br>
# Dersom de sterke ulikhetene gjelder for $\|V(x+1)-V(x)\|$ kan man anta at de også vil gjelde for $\|V(x-1)-V(x)\|$ og $\|V(x+1)-V(x-1)\|$, <br> da disse potensialforskjellene vil være av samme størrelsesorden som $\|V(x+1)-V(x)\|$. <br><br>
#
#
# I tilfellet der $k_{B}T\gg\|V(x+1)-V(x)\|$ ser vi at eksponentene i uttrykkene for $p$ vil gå mot 0, siden potensialforskjellen i telleren vil bli svært liten i forhold til $k_{B}T$ i nevneren. Vi ser da at hver av sannsynlighetene $p^{+}$, $p^{0}$ og $p^{-}$ vil gå mot 1/3.<br>
#
# $p^{+} = \lim_{x \to 0} \frac{1}{1+e^{x}+e^{x}} = \frac{1}{3}$, &emsp; $p^{0} = \lim_{x \to 0} \frac{1}{1+e^{x}+e^{x}} = \frac{1}{3}$, &emsp; $p^{-} = \lim_{x \to 0} \frac{1}{1+e^{x}+e^{x}} = \frac{1}{3}$ <br>
#
# Vi ser dermed at i tilfeller der den termiske energien er mye større enn potensialforskjellene fra en posisjon til en annen, vil det være lik sannsynlighet for at partikkelen beveger seg til høyre, venstre eller blir værende. <br> <br>
#
# I tilfellet der $k_{B}T\ll\|V(x+1)-V(x)\|$ vil eksponentene i uttrykkene for $p$ gå mot $\infty$ siden potensialforskjellen i telleren vil bli svært stor i forhold til $k_{B}T$ i nevneren. <br>
# Fortegnet til eksponenten vil derimot avhenge av potensialforskjellen, noe som gir stor innvirkning på verdiene til $p^{+}$, $p^{0}$ og $p^{-}$. <br>
# Dersom potensialet øker mot høyre ser vi for eksempel at $(V(x-1) - V(x+1)) < 0$ og at $(V(x) - V(x+1)) < 0$. Da ser vi at eksponentene i uttrykket for $p^{+} blir positive, og vi får: <br>
# $p^{+} = \lim_{x \to \infty} \frac{1}{1+e^{x}+e^{x}} = 0$ <br><br>
# For $p^{0}$ og $p^{-}$ får vi: <br>
# $p^{0} = \lim_{x \to \infty} \frac{1}{1+e^{x}+e^{-x}} = 0$, &emsp; $p^{-} = \lim_{x \to \infty} \frac{1}{1+e^{-x}+e^{-x}} = \frac{1}{1} = 1$ <br>
#
# Vi ser dermed at i tilfeller der potensialforskjellene fra en posisjon til en annen er mye større enn den termiske energien vil det være helt forutsigbart hvilken retning partikkelen vil bevege seg i. <br> Partikkelen vil alltid bevege seg i retning av det laveste potensialet, slik vi ser i eksempelet over. <br><br>
#
# Når man skal simulere spredning av partikler vil det i praksis være rimelig å anta at den termiske energien vil være vesentlig høyere enn potensialforskjellene mellom ulike posisjoner, og at disse vil operere på ulike energiskalaer. Tilfellet der $k_{B}T\gg\|V(x+1)-V(x)\|$ viste at det da vil være lik sannsynlighet for at en partikkel beveger seg i alle de mulige retningene. Dette stemmer godt overens med teorien bak "random walk", som nettopp legger til grunn at det er helt tilfeldig hvilken retning partikkelen beveger seg i.
